# %% [markdown]
# <a href="https://colab.research.google.com/github/dishajain01/Image-processing/blob/main/IMAGE_PROCESSING_CV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image="/content/jerry.webp"

# %%
img=cv2.imread(image)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1093, 1154, 3)

# %%
img.max()
# Out:
# 255

# %%
img.min()
# Out:
# 0

# %%
plt.show()
plt.imshow(img)

# %%
img_1 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_1)

# %%
plt.figure(figsize=(5,5))
plt.imshow(img_1)
plt.show()

# %%
cv2.imwrite('/content/jerry.webp',img)
# Out:
# True

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_gray.shape
# Out:
# (1093, 1154)

# %%
plt.figure(figsize=(10, 10))
plt.imshow(img_gray, cmap='gray')
plt.show()

# %%
x,y,z=img[:,:,0],img[:,:,1],img[:,:,2]
im_xyz= cv2.vconcat([x,y,z])
plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title("RGB")
plt.subplot(122)
plt.imshow(im_xyz , cmap='gray')
plt.show()

# %%
rows =547
plt.figure(figsize=(10,10))
plt.imshow(img_1[0:rows,:,:])
plt.show()

# %%
coloumns =577
plt.figure(figsize=(10,10))
plt.imshow(img_1[:,0:coloumns,:])
plt.show()

# %%
A= img_1.copy()
plt.imshow(A)
plt.show()

# %%
B = A
A[:,:,:] = 0
plt.imshow(B)
plt.show()

# %%
import numpy as np
A= img_1
id(A)
# Out:
# 140243465641392

# %%
B=img_1.copy
id(B)==id(img_1)
# Out:
# False

# %%
id(A)==id(img_1)
# Out:
# True

# %%
img_1[:,:,]=0
plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB))
plt.title("img_1")
plt.subplot(122)
plt.imshow(cv2.cvtColor(A, cv2.COLOR_BGR2RGB))
plt.title("array A")
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB))
plt.title("img_1")
plt.subplot(122)
plt.imshow(cv2.cvtColor(B, cv2.COLOR_BGR2RGB))
plt.title("array B")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-0d0d869c7514> in <module>()
#       4 plt.title("img_1")
#       5 plt.subplot(122)
# ----> 6 plt.imshow(cv2.cvtColor(B, cv2.COLOR_BGR2RGB))
#       7 plt.title("array B")
#       8 plt.show()
#
# TypeError: Expected Ptr<cv::UMat> for argument '%s'

# %% [markdown]
# FLIPPING IMAGE

# %%
image = cv2.imread("/content/jerry.webp")
plt.figure(figsize=(10,10))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
width, height,C=image.shape
print('width, height,C',width, height,C)
# Out:
# width, height,C 1093 1154 3

# %%
array_flip = np.zeros((width, height,C),dtype=np.uint8)

# %%
for i,row in enumerate(image):
        array_flip[width-1-i,:,:]=row

# %%
plt.figure(figsize=(5,5))
plt.imshow(cv2.cvtColor(array_flip, cv2.COLOR_BGR2RGB))
plt.show()

# %%
for flipcode in [0,1,-1]:
    im_flip =  cv2.flip(image,flipcode )
    plt.imshow(cv2.cvtColor(im_flip,cv2.COLOR_BGR2RGB))
    plt.title("flipcode: "+str(flipcode))
    plt.show()

# %%
im_flip = cv2.rotate(image,0)
plt.imshow(cv2.cvtColor(im_flip,cv2.COLOR_BGR2RGB))
plt.show()

# %%
flip = {"ROTATE_90_CLOCKWISE":cv2.ROTATE_90_CLOCKWISE,"ROTATE_90_COUNTERCLOCKWISE":cv2.ROTATE_90_COUNTERCLOCKWISE,"ROTATE_180":cv2.ROTATE_180}

# %%
flip["ROTATE_90_CLOCKWISE"]
# Out:
# 0

# %%
for key, value in flip.items():
    plt.subplot(1,2,1)
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title("orignal")
    plt.subplot(1,2,2)
    plt.imshow(cv2.cvtColor(cv2.rotate(image,value), cv2.COLOR_BGR2RGB))
    plt.title(key)
    plt.show()

# %% [markdown]
# CROPPING

# %%
upper = 10
lower = 600
crop_top = image[upper: lower,:,:]
plt.figure(figsize=(10,10))
plt.imshow(cv2.cvtColor(crop_top, cv2.COLOR_BGR2RGB))
plt.show()

# %%
left = 200
right = 950
crop_horizontal = crop_top[: ,left:right,:]
plt.figure(figsize=(5,5))
plt.imshow(cv2.cvtColor(crop_horizontal, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# CHANGING SPECIFIC PIXELS

# %%
array_sq = np.copy(image)
array_sq[upper:lower,left:right,:] = 0

# %%
plt.figure(figsize=(10,10))
plt.subplot(1,2,1)
plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))
plt.title("orignal")
plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(array_sq,cv2.COLOR_BGR2RGB))
plt.title("Altered Image")
plt.show()

# %%
start_point, end_point = (left, upper),(right, lower)
image_draw = np.copy(image)
cv2.rectangle(image_draw, pt1=start_point, pt2=end_point, color=(0, 255, 0), thickness=3) 
plt.figure(figsize=(5,5))
plt.imshow(cv2.cvtColor(image_draw, cv2.COLOR_BGR2RGB))
plt.show()
